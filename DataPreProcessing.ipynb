# %% [markdown]
# <a href="https://colab.research.google.com/github/cicily19/LifeExpectancyDataPreprocessing/blob/main/DataPreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Preprocessing
# This is the most crucial step in Data Science projects because it ensures that the data being analysed or machine learning model being developed is using data of high quality so as to generate quality insights
#
# ### Topics Covered
# 1. Import necessary libraries
# 2. Reading Datasets
# 3. Sanity Checks(Quick Overview)
# 4. Exploratory Data Analysis
# 5. Handling Missing Values
# 6. Handling Outliers
# 7. Handling Duplicate Records
# 8. Data Normalization(Scaling Data to a Certain Range)
# 9. Data Encoding(Label and One Hot Encoding)
#
# Data Engineers are the professionals responsible for Data Preprocessing

# %% [markdown]
# ## Step1: Importing Libraries

# %%
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step2: Reading the Dataset
# Read the Life Expectancy Dataset(WHO) Kaggle

# %%
df = pd.read_csv('/content/Life Expectancy Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# head()
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# tail
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %% [markdown]
# ## Step3: Sanity Checkup for the Dataset
# We will be identifying the following with the Dataset.
# 1. Missing Values
# 2. Outliers
# 3. Garbages
# 4. Duplicates

# %%
# shape
# (rows, columns)
df.shape
# Out:
# (2938, 22)

# %%
# info()
# Discover various datatypes in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# Finding missing values
# null represents empty
# a) drop()
# b) replace()
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# percentage of the missing values
# If a column has more than 50% of empties, then the column is deleted
# (empties/totalrecords) * 100
df.shape[0]
df.isnull().sum()/df.shape[0] * 100
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Step4: Exploratory Data Analysis

# %%
# Descriptive Statistics
# a) Numerical
df.describe().T
# df.describe().transpose()
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2928.0  6.922493e+01  9.523867e+00
# Adult Mortality                  2928.0  1.647964e+02  1.242921e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2385.0  8.094046e+01  2.507002e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
#  BMI                             2904.0  3.832125e+01  2.004403e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2919.0  8.255019e+01  2.342805e+01
# Total expenditure                2712.0  5.938190e+00  2.498320e+00
# Diphtheria                       2919.0  8.232408e+01  2.371691e+01
# ...

# %%
# b) Categorical Stats
df.describe(include='object').transpose()
# Out:
#         count unique          top  freq
# Country  2938    193  Afghanistan    16
# Status   2938      2   Developing  2426

# %%
# Data Distribution on Histograms
# They represent a Uni-Variant Analysis(Single Columns)
sns.histplot(data = df, x = df ['Life expectancy '], kde=True)
plt.title('Distribution of Life Expectancy')
plt.figure(figsize=(50,50))
plt.show()

# %%
# Distribution of All Numerical Columns
df.select_dtypes(include='number').columns
for i in df.select_dtypes(include='number').columns:
  sns.histplot(data = df, x = df[i], kde=True)
  plt.title(f'Distribution of {i}')
  plt.figure(figsize=(50,50))
  plt.show()

# %%
# OUTLIER DETECTION USING BOX-PLOTS
# Unusual Distribution within a Dataset Columns
sns.boxplot(data = df, x = df['Life expectancy '])
plt.figure(figsize=(50,50))
plt.show()

# %%
# Distribution of All Numerical Columns
df.select_dtypes(include='number').columns
for i in df.select_dtypes(include='number').columns:
  sns.boxplot(data = df, x = df[i])
  plt.title(f'Outliers in {i}')
  plt.figure(figsize=(50,50))
  plt.show()

# %%
# CORRELATION ANALYSIS
# NUMERICAL COLUMNS
correlations = df[df.select_dtypes(include='number').columns].corr()
plt.figure(figsize=(15, 15))
sns.heatmap(correlations, annot=True)
plt.show()

# %%
# LINEAR RELATIONSHIPS
# BI-VARIANT
sns.scatterplot(data=df, x='Life expectancy ', y='Adult Mortality')
plt.show()

# %%
for i in df.select_dtypes(include='number').columns:
    sns.scatterplot(data=df, x= 'Life expectancy ', y=df[i])
    plt.show()
